# %% [markdown]
# Installing Libraries

# %%
# !pip install streamlit

# %%
#importing libraries
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from PIL import Image
import streamlit as st
from sklearn.ensemble import RandomForestClassifier

# %%
#create a title and subtitles 
st.write("""
   #Diabetes Detection
   Detects if someone has diabetes using ML and Python!
   """)

# %%
#open and display an image
img=Image.open('/content/images (5).png')
st.image(img,caption='ML',use_column_width=True)

# %%
#get the data
df=pd.read_csv('/content/datasets_4511_6897_diabetes.csv')

# %%
#set a subheader
st.subheader('Data Information: ')

# %%
#show the data as a table
st.dataframe(df)

# %%
#show statistics on the data
st.write(df.describe)

# %%
#show the data as chart
chart=st.bar_chart(df)

# %%
#splitting the dataset into x and y
X=df.iloc[:,0:8].values
Y=df.iloc[:,-1].values

# %%
#splitting datset into test and train set
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
#get the inputs from the user
def get_user_inputs():
    pregnancies=st.slidebar.slider('Pregnancies',0,17,3)
    glucose=st.slidebar
